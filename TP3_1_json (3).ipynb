# %% [markdown]
# Como crear y convertir archivos son a diccionarios en python

# %%
import json
datos_json = """
{
    "tamaño": "mediana",
    "precio": 15.67,
    "toppings":["champignones", "pepperoni", "albahaca"],
    "queso": false,
    "delibery": true,
    "cliente": {
       "nombre": "Jane Doe",
       "telefono": null,
       "correo": "janedoe@email.com"
    }
  } """
#print(f"tipo de dato: {type(datos_json)}")
#print(datos_json)

#print("\nPara compartit un archivo .json a un diccionario en python utilizo la función json.loads(archivo.json)\ny envío archivo.json como parámetro")
diccionario = json.loads(datos_json)
#print(f"tipo de dato: {type(diccionario)}")
#print(diccionario)
#print(diccionario.get('precio'))

print("\nPara convertir un diccionario .json utilizo una funcion json.dumps(diccionario)\ny envio el diccionario")
nuevo_json = json.dumps(diccionario)
print("Archivo convertido a string")
print(nuevo_json)
#print(nuevo_json.get('precio'))
# Out:
# Para convertir un diccionario .json utilizo una funcion json.dumps(diccionario)
# y envio el diccionario
# Archivo convertido a string
# {"tama\u00f1o": "mediana", "precio": 15.67, "toppings": ["champignones", "pepperoni", "albahaca"], "queso": false, "delibery": true, "cliente": {"nombre": "Jane Doe", "telefono": null, "correo": "janedoe@email.com"}}

# %% [markdown]
# Ejemplos con diccionarios creados en clase
#
# *   convertir diccionarios a archivos json y viseversa
# *   visualización de datos en formato diccionario y formato json

# %%
import json

campeon_mundial = {
    1986: "Argentina",
    1990: "Alemania",
    1994: "Brasil",
    1998: "Francia",
    2002: "Brasil",
    2006: "Italia",
    2010: "España",
    2014: "Alemania",
    2018: "Francia",
    2022: "Argentina"}
#convierto el diccionario python a json:
archivo_json = json.dumps(campeon_mundial)
print(type(archivo_json))
#convierto el archivo json a diccionario python
nuevo_diccionario = json.loads(archivo_json)
print(type(nuevo_diccionario))
# Out:
# <class 'str'>
# <class 'dict'>

# %% [markdown]
# Python y sus reasignacion a json y viceversa

# %%
import json

campeon_mundial = {
    1986: "Argentina",
    1990: "Alemania",
    1994: "Brasil",
    1998: "Francia",
    2002: "Brasil",
    2006: "Italia",
    2010: "España",
    2014: "Alemania",
    2018: "Francia",
    2022: "Argentina"}
archivo_json = json.dumps(campeon_mundial)
#print(f"archivo_json es de tipo de dato: {type(archivo_json)} \ny su contenido es: {archivo_json}")
nuevo_diccionario = json.loads(archivo_json)
print(f"nuevo_diccionario es de tipo de dato: {type(nuevo_diccionario)} \ny su contenido es:\n{nuevo_diccionario}")
# Out:
# nuevo_diccionario es de tipo de dato: <class 'dict'>
# y su contenido es:
# {'1986': 'Argentina', '1990': 'Alemania', '1994': 'Brasil', '1998': 'Francia', '2002': 'Brasil', '2006': 'Italia', '2010': 'España', '2014': 'Alemania', '2018': 'Francia', '2022': 'Argentina'}

# %% [markdown]
# Cuando intentamos acceder a los datos clave y valor de json

# %%
import json

campeon_mundial = {
    1986: "Argentina",
    1990: "Alemania",
    1994: "Brasil",
    1998: "Francia",
    2002: "Brasil",
    2006: "Italia",
    2010: "España",
    2014: "Alemania",
    2018: "Francia",
    2022: "Argentina"}
archivo_json = json.dumps(campeon_mundial, indent=4) #se agrega indent=4 para facilitar lectura
print(f"archivo_json es de tipo de dato: {type(archivo_json)} \ny su contenido es: {archivo_json}")
nuevo_diccionario = json.loads(archivo_json)
#print(f"nuevo_diccionario es de tipo de dato: {type(nuevo_diccionario)} \ny su contenido es:\n{nuevo_diccionario}")
nuevo_diccionario['1978']="Argentina"
#print(nuevo_diccionario) #se agrega un nuevo año y campeón
#print(nuevo_diccionario['1978']) #si quiero mostrar un campeón en particular agrego [] y su año
#print(nuevo_diccionario['1986'])
#print(nuevo_diccionario['2022'])
# Out:
# archivo_json es de tipo de dato: <class 'str'>
# y su contenido es: {
#     "1986": "Argentina",
#     "1990": "Alemania",
#     "1994": "Brasil",
#     "1998": "Francia",
#     "2002": "Brasil",
#     "2006": "Italia",
#     "2010": "Espa\u00f1a",
#     "2014": "Alemania",
#     "2018": "Francia",
#     "2022": "Argentina"
# }

# %% [markdown]
# Actividad para el Grupo 1 - Maria Evangelina Dioli - Paula Nicole Cardozo
#
# Trabajo colaborativo en github
#
# Dado el siguiente archivo json:
#
#
#
# *   Importar el módulo json
# *   Definir una función para convertir el archivo json a diccionario
# *   Crear un diccionario en donde la clave sean los atributos de la clase Alumno, (tener en cuanta que la clase Alumno tiene sus atributos más los que hereda de la clase Persona) y los valores será los datos guardados en dichos atributos.
# *   Mostrar el diccionario y el archivo json

# %%
import json

import random as rd
class Persona:
  def __init__(self, nombre="", apellido="", edad=0, dni=0): #constructor con parámetros
    self.__nombre = nombre
    self.__apellido = apellido
    self.__edad = edad
    self.__dni = dni

  @property
  def nombre(self):
    return self.__nombre
  @property
  def apellido(self):
    return self.__apellido
  @property
  def edad(self):
    return self.__edad
  @property
  def dni(self):
    return self.__dni

  @nombre.setter
  def nombre(self, nombre):
    self.__nombre = nombre
  @apellido.setter
  def apellido(self, apellido):
    self.__apellido = apellido
  @edad.setter
  def edad(self, edad):
    self.__edad = edad
  @dni.setter
  def dni(self, dni):
    self.__dni = dni

  def __str__(self):
    return f"Nombre: {self.nombre}, Apellido: {self.apellido}, edad: {self.edad}, dni: {self.dni}"

#pedro = Persona("Pedro", "Martinez",24, 37654321)
#maria = Persona("Maria","Liendro", 20, 40123456)
#print(pedro)
#print(maria)

class Maestro(Persona):
  def __init__(self, nombre, apellido, edad, dni, legajo, materias):
    super().__init__(nombre, apellido, edad, dni)
    self.__legajo = legajo
    self.__materias = materias

  def get_legajo(self):
    return self.__legajo
  def get_materias(self):
    return self.__materias

  def set_legajo(self, legajo):
    self.__legajo = legajo
  def set_materia(self, materia):
    self.__materias.append(materia)
    print(f"La materia {materia} se agrego con éxito.")
  def eliminar_materia(self, materia):
    if materia in self.__materias:
      self.__materias.remove(materia)
      print(f"La materia {materia} fue eliminada")
    else:
      print(f"El docente no dicta la materia {materia}")
  def __str__(self):
    return super().__str__() + f", legajo: {self.get_legajo()}, Materias: {self.get_materias()}"

#maestro1 = Maestro("Luis", "Garcia", 49, 25321321, 9876, ["Lengua", "matemática", "Historia", "Geografía"])
#print(maestro1)
#maestro1.set_materia("Ingles")
#print(maestro1)
# tarea hacer un metodo que elimine una materia de la clase Maestro

class Alumno(Persona):
  def __init__(self,  nombre, apellido, edad, dni, grado, turno, materias):
    super().__init__(nombre, apellido, edad, dni)
    self.__grado = grado
    self.__turno = turno
    self.__materias = materias
    self.__notas = []
    self.__comision = "No asignada"

  def get_grado(self):
    return self.__grado
  def get_turno(self):
    return self.__turno
  def get_comision(self):
    return self.__comision
  def generar_notas(self, cant):
    for i in range(cant):
      self.__notas.append(rd.randint(0,10))

  def mostrar_notas(self):
    if len(self.__notas) > 0:
      cadena = ""
      for i in range(len(self.__materias)):
        cadena = cadena + self.__materias[i] + ": " + str(self.__notas[i]) + "\n"
      return cadena
    else:
      return "No hay notas cargadas"
  def promedio(self):
    if len(self.__notas) > 0:
      return sum(self.__notas) / len(self.__notas)
    else:
      print("No hay notas cargadas")
      return 0
  def asignar_comision(self, prom):
    if self.edad < 17:
      if prom >= 8:
        self.__comision = "A"
      elif prom >= 6:
        self.__comision = "B"
      else:
        self.__comision = "C"
    else:
      self.__comision = "N"
  def set_grado(self, grado):
    self.__grado = grado
  def set_turno(self, turno):
    self.__turno = turno

  def __str__(self):
    return "Alumno/a: " + super().__str__() + f", Grado {self.get_grado()}, turno: {self.get_turno()}, Comision: {self.get_comision()}\nNotas: {self.mostrar_notas()}\n"

  # Crear un diccionario en donde la clave sea los atributos de la clase Alumno, y los valores serán los datos guardados en dichos atributos. (Hecho por Nicole)
  def crear_diccionario(self):
    diccionario = {
      "nombre": self.nombre,
      "apellido": self.apellido,
      "edad": self.edad,
      "dni": self.dni,
      "grado": self.get_grado(),
      "turno": self.get_turno(),
      "materias": self.__materias,
      "notas": self.__notas,
      "comision": self.get_comision()
    }
    return diccionario
class Preceptor(Persona):
  def __init__(self, nombre, apellido, edad, dni):
    super().__init__(nombre, apellido, edad, dni)
    self.__comision = []
    self.__lista_alumnos = []

  def get_comision(self):
    return self.__comision
  def get_lista_alumnos(self):
    return self.__lista_alumnos

  def set_comision(self, comision):
    self.__comision.append(comision)
  def eliminar_comision(self, comision):
    if comision in self.__comision:
      self.__comision.remove(comision)
      print(f"La comision {comision} fue eliminada")
    else:
      print(f"El/la preceptora no está asignada a la comision {comision}")
  def set_agregar_alumno(self, alumno):
    if not alumno in self.__lista_alumnos:
      self.__lista_alumnos.append(alumno)
    else:
      print("el alumno ya está en la lista")
  def set_eliminar_alumno(self, alumno):
    if alumno in self.__lista_alumnos:
      self.__lista_alumnos.remove(alumno)
      print("Alumno eliminado con éxito.")
    else:
      print(f"El alumno que desea eliminar no está  en la lista")

  def mostrar_lista_alumnos(self):
    if len(self.__lista_alumnos) > 0:
      for i in range(len(self.__lista_alumnos)):
        print(self.__lista_alumnos[i])
    else:
      print("La lista de alumnos está vacía.")
  def __str__(self):
    return "Preceptor/a: " + super().__str__() + f", Comisiones asignadas {self.get_comision()}"



#preceptor1 = Preceptor("Maria", "Carreras", 29, 33888444)
#preceptor1.set_comision("A")
#preceptor1.set_comision("B")
#print(preceptor1)
#alumno2 = Alumno("Lisa", "Simpson", 9, 44321543, 4, "mañana", ["Lengua", "matemática", "Historia", "Geografía"])
#alumno2.asignar_comision(alumno2.promedio())
#preceptor1.set_agregar_alumno(alumno1)
#preceptor1.set_agregar_alumno(alumno2)
#preceptor1.mostrar_lista_alumnos()
#preceptor1.eliminar_comision("A")
#print(preceptor1)


# Definir una función para convertir el archivo JSON a diccionario. (Hecho por Nicole)
def json_a_diccionario(nombre_archivo):
    with open(nombre_archivo, 'r') as f:
        contenido = f.read()
        diccionario = json.loads(contenido)
    print("Conversion de JSON a diccionario realizado con éxito!")
    return diccionario

# Definir una función para convertir el diccionario en un archivo JSON. (Hecho por Evangelina)
def diccionario_a_json(diccionario, nombre_archivo):
    with open(nombre_archivo, 'w') as f:
        json.dump(diccionario, f, indent=4, ensure_ascii=False)
    print("Conversion de diccionario a JSON realizado con éxito!")

# Mostrar el diccionario y el archivo JSON. (Hecho por Evangelina)
def mostrar_resultados(diccionario, archivo_json):
    print("Diccionario:")
    print(type(diccionario))
    print(diccionario)
    print("Archivo JSON:")
    contenido = open(archivo_json).read()
    print(type(contenido))
    print(contenido)


alumno = Alumno("Bartolomeo", "Simpson", 18, 47321456, 5, "mañana", ["Lengua", "matemática", "Historia", "Geografía"])

alumno.generar_notas(4)
alumno.asignar_comision(alumno.promedio())

archivo_json = "alumno.json"

print("\nJSON A DICCIONARIO")
diccionario = json_a_diccionario(archivo_json)

print("\nJSON A DICCIONARIO")
diccionario = json_a_diccionario(archivo_json)

print("\nJSON A DICCIONARIO")
mostrar_resultados(diccionario, archivo_json)
# Out:
# JSON A DICCIONARIO
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-15a510f48e11> in <cell line: 229>()
#     227
#     228 print("\nJSON A DICCIONARIO")
# --> 229 diccionario = json_a_diccionario(archivo_json)
#     230
#     231 print("\nJSON A DICCIONARIO")
#
# <ipython-input-3-15a510f48e11> in json_a_diccionario(nombre_archivo)
#     196 # Definir una función para convertir el archivo JSON a diccionario. (Hecho por Nicole)
#     197 def json_a_diccionario(nombre_archivo):
# --> 198     with open(nombre_archivo, 'r') as f:
#     199         contenido = f.read()
#     200         diccionario = json.loads(contenido)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'alumno.json'

# %%
# Importar el módulo JSON. (Hecho por Nicole y Evangelina)
import json

import random as rd
class Persona:
  def __init__(self, nombre="", apellido="", edad=0, dni=0): # constructor con parametros
    self.__nombre = nombre
    self.__apellido = apellido
    self.__edad = edad
    self.__dni = dni

  @property
  def nombre(self):
    return self.__nombre
  @property
  def apellido(self):
    return self.__apellido
  @property
  def edad(self):
    return self.__edad
  @property
  def dni(self):
    return self.__dni

  @nombre.setter
  def nombre(self, nombre):
    self.__nombre = nombre
  @apellido.setter
  def apellido(self, apellido):
    self.__apellido = apellido
  @edad.setter
  def edad(self, edad):
    self.__edad = edad
  @dni.setter
  def dni(self, dni):
    self.__dni = dni

  def __str__(self):
    return f"Nombre: {self.nombre}, Apellido: {self.apellido}, edad: {self.edad}, dni: {self.dni}"

#pedro = Persona("Pedro", "Martinez",24, 37654321)
#maria = Persona("Maria","Liendro", 20, 40123456)
#print(pedro)
#print(maria)

class Maestro(Persona):
  def __init__(self, nombre, apellido, edad, dni, legajo, materias):
    super().__init__(nombre, apellido, edad, dni)
    self.__legajo = legajo
    self.__materias = materias

  def get_legajo(self):
    return self.__legajo
  def get_materias(self):
    return self.__materias

  def set_legajo(self, legajo):
    self.__legajo = legajo
  def set_materia(self, materia):
    self.__materias.append(materia)
    print(f"La materia {materia} se agrego con éxito.")
  def eliminar_materia(self, materia):
    if materia in self.__materias:
      self.__materias.remove(materia)
      print(f"La materia {materia} fue eliminada")
    else:
      print(f"El docente no dicta la materia {materia}")
  def __str__(self):
    return super().__str__() + f", legajo: {self.get_legajo()}, Materias: {self.get_materias()}"

#maestro1 = Maestro("Luis", "Garcia", 49, 25321321, 9876, ["Lengua", "matemática", "Historia", "Geografía"])
#print(maestro1)
#maestro1.set_materia("Ingles")
#print(maestro1)
# tarea hacer un metodo que elimine una materia de la clase Maestro

class Alumno(Persona):
  def __init__(self,  nombre, apellido, edad, dni, grado, turno, materias):
    super().__init__(nombre, apellido, edad, dni)
    self.__grado = grado
    self.__turno = turno
    self.__materias = materias
    self.__notas = []
    self.__comision = "No asignada"

  def get_grado(self):
    return self.__grado
  def get_turno(self):
    return self.__turno
  def get_comision(self):
    return self.__comision
  def generar_notas(self, cant):
    for i in range(cant):
      self.__notas.append(rd.randint(0,10))

  def mostrar_notas(self):
    if len(self.__notas) > 0:
      cadena = ""
      for i in range(len(self.__materias)):
        cadena = cadena + self.__materias[i] + ": " + str(self.__notas[i]) + "\n"
      return cadena
    else:
      return "No hay notas cargadas"
  def promedio(self):
    if len(self.__notas) > 0:
      return sum(self.__notas) / len(self.__notas)
    else:
      print("No hay notas cargadas")
      return 0
  def asignar_comision(self, prom):
    if self.edad < 17:
      if prom >= 8:
        self.__comision = "A"
      elif prom >= 6:
        self.__comision = "B"
      else:
        self.__comision = "C"
    else:
      self.__comision = "N"
  def set_grado(self, grado):
    self.__grado = grado
  def set_turno(self, turno):
    self.__turno = turno

  def __str__(self):
    return "Alumno/a: " + super().__str__() + f", Grado {self.get_grado()}, turno: {self.get_turno()}, Comision: {self.get_comision()}\nNotas: {self.mostrar_notas()}\n"

  # Crear un diccionario en donde la clave sea los atributos de la clase Alumno, y los valores serán los datos guardados en dichos atributos. (Hecho por Nicole)
  def crear_diccionario(self):
    diccionario = {
      "nombre": self.nombre,
      "apellido": self.apellido,
      "edad": self.edad,
      "dni": self.dni,
      "grado": self.get_grado(),
      "turno": self.get_turno(),
      "materias": self.__materias,
      "notas": self.__notas,
      "comision": self.get_comision()
    }
    return diccionario
class Preceptor(Persona):
  def __init__(self, nombre, apellido, edad, dni):
    super().__init__(nombre, apellido, edad, dni)
    self.__comision = []
    self.__lista_alumnos = []

  def get_comision(self):
    return self.__comision
  def get_lista_alumnos(self):
    return self.__lista_alumnos

  def set_comision(self, comision):
    self.__comision.append(comision)
  def eliminar_comision(self, comision):
    if comision in self.__comision:
      self.__comision.remove(comision)
      print(f"La comision {comision} fue eliminada")
    else:
      print(f"El/la preceptora no está asignada a la comision {comision}")
  def set_agregar_alumno(self, alumno):
    if not alumno in self.__lista_alumnos:
      self.__lista_alumnos.append(alumno)
    else:
      print("el alumno ya está en la lista")
  def set_eliminar_alumno(self, alumno):
    if alumno in self.__lista_alumnos:
      self.__lista_alumnos.remove(alumno)
      print("Alumno eliminado con éxito.")
    else:
      print(f"El alumno que desea eliminar no está  en la lista")

  def mostrar_lista_alumnos(self):
    if len(self.__lista_alumnos) > 0:
      for i in range(len(self.__lista_alumnos)):
        print(self.__lista_alumnos[i])
    else:
      print("La lista de alumnos está vacía.")
  def __str__(self):
    return "Preceptor/a: " + super().__str__() + f", Comisiones asignadas {self.get_comision()}"



#preceptor1 = Preceptor("Maria", "Carreras", 29, 33888444)
#preceptor1.set_comision("A")
#preceptor1.set_comision("B")
#print(preceptor1)
#alumno2 = Alumno("Lisa", "Simpson", 9, 44321543, 4, "mañana", ["Lengua", "matemática", "Historia", "Geografía"])
#alumno2.asignar_comision(alumno2.promedio())
#preceptor1.set_agregar_alumno(alumno1)
#preceptor1.set_agregar_alumno(alumno2)
#preceptor1.mostrar_lista_alumnos()
#preceptor1.eliminar_comision("A")
#print(preceptor1)


# Definir una función para convertir el archivo JSON a diccionario. (Hecho por Nicole)
def json_a_diccionario(nombre_archivo):
    with open(nombre_archivo, 'r') as f:
        contenido = f.read()
        diccionario = json.loads(contenido)
    print("Conversion de JSON a diccionario realizado con éxito!")
    return diccionario

# Definir una función para convertir el diccionario en un archivo JSON. (Hecho por Evangelina)
def diccionario_a_json(diccionario, nombre_archivo):
    with open(nombre_archivo, 'w') as f:
        json.dump(diccionario, f, indent=4, ensure_ascii=False)
    print("Conversion de diccionario a JSON realizado con éxito!")

# Mostrar el diccionario y el archivo JSON. (Hecho por Evangelina)
def mostrar_resultados(diccionario, archivo_json):
    print("Diccionario:")
    print(type(diccionario))
    print(diccionario)
    print("Archivo JSON:")
    contenido = open(archivo_json).read()
    print(type(contenido))
    print(contenido)


alumno = Alumno("Bartolomeo", "Simpson", 18, 47321456, 5, "mañana", ["Lengua", "matemática", "Historia", "Geografía"])

alumno.generar_notas(4)
alumno.asignar_comision(alumno.promedio())

archivo_json = "alumno.json"

print("\nJSON A DICCIONARIO")
diccionario = json_a_diccionario(archivo_json)

print("\nJSON A DICCIONARIO")
diccionario = json_a_diccionario(archivo_json)

print("\nJSON A DICCIONARIO")
mostrar_resultados(diccionario, archivo_json)
# Out:
# JSON A DICCIONARIO
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5f4c7a9a9891> in <cell line: 230>()
#     228
#     229 print("\nJSON A DICCIONARIO")
# --> 230 diccionario = json_a_diccionario(archivo_json)
#     231
#     232 print("\nJSON A DICCIONARIO")
#
# <ipython-input-4-5f4c7a9a9891> in json_a_diccionario(nombre_archivo)
#     197 # Definir una función para convertir el archivo JSON a diccionario. (Hecho por Nicole)
#     198 def json_a_diccionario(nombre_archivo):
# --> 199     with open(nombre_archivo, 'r') as f:
#     200         contenido = f.read()
#     201         diccionario = json.loads(contenido)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'alumno.json'

# %% [markdown]
# Actividad para el Grupo 2: Patricia Guzmán y Maria Luisa Costas
#
# Trabajo colaborativo en github
#
# Dado el siguiente archivo json:
#
#
# *   Importar el módulo json
# *   Definir una función para convertir el archivo json a diccionario
# *   Agregar los horarios del turno tarde, 15:00, 15:30, 16:00 y 16:30
# *   Asigne al menos dos pacientes al turno mañana y dos al turno tarde
# *   Definir una Función para convertir el diccionario en un archivo json
# *   Mostrar el diccionario y el archivo json

# %%
turnos_son = """{ '08:00': '',
          '08:30': '',
          '09:00': '',
          '09:30': '',
          '10:00': '',
          '10:30': '',
          '11:00': '',
          '11:30': '',
          '12:00': '',
          '12:30': '' }"""
"""
turnos = { '08:00': '',
          '08:30': '',
          '09:00': '',
          '09:30': '',
          '10:00': '',
          '10:30': '',
          '11:00': '',
          '11:30': '',
          '12:00': '',
          '12:30': '' }
respuesta = "si"
while respuesta == "si":
  apellido = input("Ingrese el apellido del paciente: ")
  horario = input("Ingrese el horario elegido (HH:MM): ")
  band = True
  for clave, valor in turnos.items():
    if band == True:
      if horario == clave and len(valor) == 0:
        turnos[clave] = apellido
        print("Turno confirmado")
        band = False
      else:
        print("Turno no disponible")
  respuesta= input("Desea seguir ingresando (si o no): ")
print(turnos)"""

# %% [markdown]
# Actividad para el Grupo 3 - Pamela Salva y Cecilia Silvana Salva
#
# Trabajo colaborativo en github
#
# Dado el siguiente archivo json:
#
#
# *   Importar el módulo json
# *   Definir una función para convertir el archivo json a diccionario
# *   Crear un diccionario en donde la clave sean los elementos de lista1 y los valores de lista2
# *   Agregar el alumnX López con las notas(75,83,100) al diccionario
# *   Definit una función para convertir el diccionario en un archivo json
# *   Mostrar el diccionario y el archivo json

# %%
lista1 = ["Guzman", "Luna", "Cardozo", "Belmonte", "Vilte"]
lista2 = [[50, 75, 20], [100, 90, 60], [10, 50, 100], [50, 50, 60], [80, 85, 60]]
lista3 = []
lista4 = []
cont1 = 0
mayorNota = 0
ind = 0
for indice in range(len(lista1)):
  print(lista1[indice], "las notas son: ",(lista2[indice]))
  suma = 0
  ban = 1
  cont2 = 0
  for nota in lista2[indice]:
    cont2 += 1
    if nota >= 60:
      suma = suma + nota
    if ban == 1:
      ban = 0
    if nota > mayorNota:
      mayorNota = nota
      ind = indice
    if cont2 == 2:
      if nota < 60:
        lista4.append(lista1[indice])
  if suma >= 100:
    cont1 += 1
print ("")
print("Cantidad de alumnos que aprobaron los 3 examenes con notas >= 60: ", cont1)
print("Alumno con mayor nota en el 1er parcial: ", lista1[ind])
print("Alumno que deben recuperar el 2do parcial: ", lista4)

# %% [markdown]
# Actividad para el Grupo 4 -Elizabet Rosalina Moreno y Elder Patricia Serrano
#
# Trabajo colaborativo en github
#
# Dado el siguiente archivo json:
#
# *   Importar el módulo json
# *   Definir una función para convertir el archivo json a diccionario
# *   Agregar la divisa bitcoin con el valor de 30500
# *   Para conprar bitcoin con pesos, antes debe comprar dolares y luego con los dolares puede comprar bitcoin
# *   Definir una función para convertir el diccionario en un archivo json
# *   Mostrar el diccionario y el archivo json

# %%
import json

divisa_json = '''{'Euro': 550,'Dolar': 500,'Yen': 5.67, 'Libra': 485.16}'''

# Defino una función para convertir el archivo json a diccionario
def cargar_divisas(json_data):
    diccionario = json.loads(json_data)
    return diccionario

def convertir_a_json(diccionario):
    json_data = json.dumps(diccionario, indent=4)
    return json_data

def divisa_disponible(divisa, *args):
    return divisa in args

def cambio_divisa(**kwargs):
    if divisa in diccionario:
      valor = diccionario[divisa]
      cambio = round(pesos / valor, 2)
    return cambio

dic_divisa = {'Euro':'E','Dolar':'$','Yen':'Y','Real':'R','Libra':'L'}
dic_divisa_2 = cargar_divisas(divisa_json)

dic_divisa_2["Bitcoin"] = 30500

band = "si"
while band == "si":
    divisa = input("Ingrese un tipo de divisa: ")
    pesos = float(input("Ingrese la cantidad de pesos que desea cambiar: "))

    if divisa == 'Bitcoin':
        divisa_dolar = 'Dolar'
        cambio_dolar = cambio_divisa(pesos, divisa_dolar, dic_divisa_2)
        if cambio_dolar is None:
            print(f"Con {pesos} no se puede comprar Bitcoin")
        else:
            cambio_bitcoin = cambio_divisa(cambio_dolar, divisa, dic_divisa_2)
            if cambio_bitcoin is not None:
                print(f"Con {pesos} puede comprar {cambio_bitcoin} Bitcoin")

    else:
        band2 = divisa_disponible(divisa, *dic_divisa_2.keys())

        if band2:
            print(f"La divisa {dic_divisa[divisa]} {divisa} esta disponible")
        else:
            print(f"La divisa {divisa} no está disponible")
        if band2:
            cambio = cambio_divisa(pesos, divisa, dic_divisa_2)
        if cambio is not None:
            print(f"El cambio de $  {pesos } a {divisa} es {dic_divisa[divisa]} {cambio}")
    band = input("Desea realizar otro cambio? si / no: ")

print("Diccionario: ")
print(dic_divisa_2)

json_data=convertir_a_json(dic_divisa_2)
print("Archivo Json: ")
print(json_data)

print("Fin del programa.")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-68a35ed944d3> in <cell line: 24>()
#      22
#      23 dic_divisa = {'Euro':'E','Dolar':'$','Yen':'Y','Real':'R','Libra':'L'}
# ---> 24 dic_divisa_2 = cargar_divisas(divisa_json)
#      25
#      26 dic_divisa_2["Bitcoin"] = 30500
#
# <ipython-input-1-68a35ed944d3> in cargar_divisas(json_data)
#       5 # Defino una función para convertir el archivo json a diccionario
#       6 def cargar_divisas(json_data):
# ----> 7     diccionario = json.loads(json_data)
#       8     return diccionario
#       9
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
import json

divisa_json = '''{"Euro": 550, "Dolar": 500, "Yen": 5.67, "Libra": 485.16}'''

def cargar_divisas(json_data):
    diccionario = json.loads(json_data)
    return diccionario

def convertir_a_json(diccionario):
    json_data = json.dumps(diccionario, indent=4)
    return json_data

def divisa_disponible(divisa, *args):
    return divisa in args

def cambio_divisa(cant_dinero, divisa, diccionario):
    if divisa in diccionario:
        valor = diccionario[divisa]
        cambio = round(cant_dinero / valor, 2)
        return cambio
def muestra_menu():
  opcion=0
  while opcion!=4:
    print("1.Cambiar divisas")
    print("2.Agregar divisas")
    print("3.Modificar valor del cambio")
    print("4.Salir")
    opcion=int(input("Ingrese la opción deseada: "))
    if opcion==1:
      band = "si"
      while band == "si":
        print("============================================================") #Agregue código para imprimir por pantalla la tabla con las divisas
        print(f"{'Tasa de cambio': ^15}")                                       #disponibles y la tasa de cambio
        print("============================================================")
        print(f"{'Divisa': <20} {'Tasa de cambio':^15}")
        for divisa,tasa in dic_divisa_2.items():
          print(f'{divisa}                       {tasa:.2f}')
        divisa = input("Ingrese un tipo de divisa: ")
        disp = divisa_disponible(divisa, *dic_divisa_2.keys())
        if not disp:
          print(f"La divisa {divisa} no está disponible.")
        else:
          cant_dinero = float(input("Ingrese la cantidad de pesos que desea cambiar: "))
          if divisa == 'Bitcoin':
            resp=input("Para cambiar Bitcoins, debe primero comprar dólares, desea continuar?(si/no: )")
            if resp=="si":
              divisa="Dolar"
              cambio_dolar= cambio_divisa(cant_dinero,divisa,dic_divisa_2)
              print(f"El cambio de {cant_dinero } a {divisa} es {dic_divisa[divisa]} {cambio_dolar}")
              divisa="Bitcoin"
              cambio_bitcoin=cambio_divisa(cant_dinero,divisa,dic_divisa_2)
              print(f"El cambio de {cant_dinero } a {divisa} es {cambio_bitcoin}")
          else:
            cambio= cambio_divisa(cant_dinero,divisa,dic_divisa_2)
            print(f"El cambio de ${cant_dinero} a {divisa} es {dic_divisa[divisa]} {cambio}")
        band = input("Desea realizar otro cambio? si / no: ")
    elif opcion==2:
      divisa=input("Ingrese la nueva divisa: ")
      valor=float(input("Ingrese la taza de cambio de la nueva divisa: "))
      dic_divisa_2[divisa]=valor
      print(dic_divisa_2)
    elif opcion==3:
      divisa=input("Ingrese la divisa que desea modificar: ")
      valor=float(input("Ingrese el nuevo valor de la tasa de cambio: "))
      dic_divisa_2[divisa]=valor
      print(dic_divisa_2)
    else:
      if opcion==4:
       print("Fin del programa")

dic_divisa = {'Euro': 'E', 'Dolar': '$', 'Yen': 'Y', 'Real': 'R', 'Libra': 'L'}
dic_divisa_2 = cargar_divisas(divisa_json)
print("Diccionario:")
print(dic_divisa_2)
muestra_menu()
json_data = convertir_a_json(dic_divisa_2)
print("Archivo JSON:")
print(json_data)
# Out:
# Diccionario:
# {'Euro': 550, 'Dolar': 500, 'Yen': 5.67, 'Libra': 485.16}
# 1.Cambiar divisas
# 2.Agregar divisas
# 3.Modificar valor del cambio
# 4.Salir
# Ingrese la opción deseada: 2
# Ingrese la nueva divisa: Bitcoin
# Ingrese la taza de cambio de la nueva divisa: 30500
# {'Euro': 550, 'Dolar': 500, 'Yen': 5.67, 'Libra': 485.16, 'Bitcoin': 30500.0}
# 1.Cambiar divisas
# 2.Agregar divisas
# 3.Modificar valor del cambio
# 4.Salir
# Ingrese la opción deseada: 1
# ============================================================
# Tasa de cambio
# ============================================================
# Divisa               Tasa de cambio
# Euro                       550.00
# Dolar                       500.00
# Yen                       5.67
# Libra                       485.16
# Bitcoin                       30500.00
# Ingrese un tipo de divisa: Bitcoin
# Ingrese la cantidad de pesos que desea cambiar: 10000
# Para cambiar Bitcoins, debe primero comprar dólares, desea continuar?(si/no: )si
# El cambio de 10000.0 a Dolar es $ 20.0
# El cambio de 10000.0 a Bitcoin es 0.33
# Desea realizar otro cambio? si / no: si
# ============================================================
# Tasa de cambio
# ============================================================
# Divisa               Tasa de cambio
# Euro                       550.00
# Dolar                       500.00
# Yen                       5.67
# Libra                       485.16
# Bitcoin                       30500.00
# Ingrese un tipo de divisa: g
# La divisa g no está disponible.
# Desea realizar otro cambio? si / no: no
# 1.Cambiar divisas
# 2.Agregar divisas
# 3.Modificar valor del cambio
# 4.Salir
# Ingrese la opción deseada: 3
# Ingrese la divisa que desea modificar: Dolar
# Ingrese el nuevo valor de la tasa de cambio: 600
# {'Euro': 550, 'Dolar': 600.0, 'Yen': 5.67, 'Libra': 485.16, 'Bitcoin': 30500.0}
# 1.Cambiar divisas
# 2.Agregar divisas
# 3.Modificar valor del cambio
# 4.Salir
# Ingrese la opción deseada: 4
# Fin del programa
# Archivo JSON:
# {
#     "Euro": 550,
#     "Dolar": 600.0,
#     "Yen": 5.67,
#     "Libra": 485.16,
#     "Bitcoin": 30500.0
# }
# 'band = "si"\nwhile band == "si":\n  cambio=0\n  print("============================================================") #Agregue código para imprimir por pantalla la tabla con las divisas\n  print(f"{\'Tasa de cambio\': ^15}")                                       #disponibles y la tasa de cambio\n  print("============================================================")\n  print(f"{\'Divisa\': <20} {\'Tasa de cambio\':^15}")\n  for divisa,tasa in dic_divisa_2.items():\n    print(f\'{divisa}                       {tasa:.2f}\')\n  divisa = input("Ingrese un tipo de divisa: ")\n  disp = divisa_disponible(divisa, *dic_divisa_2.keys())\n  if not disp:\n    print(f"La divisa {divisa} no está disponible.")\n  else:\n    cant_dinero = float(input("Ingrese la cantidad de pesos que desea cambiar: "))\n    if divisa == \'Bitcoin\':\n      resp=input("Para cambiar Bitcoins, debe primero comprar dólares, desea continuar?(si/no: )")\n      if resp=="si":\n        divisa="Dolar"\n        cambio_dolar= cambio_divisa(cant_dinero,divisa,dic_divisa_2)\n        print(f"El cambio de {cant_dinero } a {divisa} es {dic_divisa[divisa]} {cambio_dolar}")\n        divisa="Bitcoin"\n        cambio_bitcoin=cambio_divisa(cant_dinero,divisa,dic_divisa_2)\n        print(f"El cambio de {cant_dinero } a {divisa} es {cambio_bitcoin}")\n    else:\n      band2 = divisa_disponible(divisa, *dic_divisa_2.keys())\n      if band2:\n        print(f"La divisa {dic_divisa[divisa]} {divisa} está disponible.")\n      else:\n        print(f"La divisa {divisa} no está disponible.")\n      if band2:\n        cambio = cambio_divisa(cant_dinero, divisa, dic_divisa_2)\n        if cambio is not None:\n          print(f"El cambio de ${cant_dinero} a {divisa} es {dic_divisa[divisa]} {cambio}")\n        \n  band = input("Desea realizar otro cambio? si / no: ")'

# %% [markdown]
# En esta versión actualizada, se han realizado los siguientes cambios:
#
# 1. Se ha importado el módulo json.
#
# 2. Se ha agregado la función cargar_divisas para convertir el archivo JSON a un diccionario.
# 3. Se ha agregado la función convertir_a_json para convertir el diccionario en formato JSON.
# 4. Se ha agregado la divisa "Bitcoin" con un valor de 30500 en el diccionario dic_divisa_2.
# 5. Se ha modificado la lógica para permitir comprar Bitcoin. Primero, se verifica si la divisa ingresada es "Bitcoin". En ese caso, se realiza la conversión de pesos a dólares y luego de dólares a Bitcoin.
# 6. Se muestra el diccionario y el archivo JSON resultantes al final del programa.
#
# Con estas modificaciones, el programa permite realizar cambios de divisas con pesos y también muestra el diccionario actualizado y el archivo JSON correspondiente.
